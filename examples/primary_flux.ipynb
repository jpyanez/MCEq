# %% [markdown]
# Dependence on primary cosmic ray flux
# -----------------------------------

# %%
#basic imports and ipython setup
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
import os
import matplotlib.pyplot as plt
import numpy as np
os.chdir('..')

#import solver related modules
from MCEq.core import MCEqRun
from mceq_config import config
#import primary model choices
import CRFluxModels as pm

# %% [markdown]
# Create an instance of an MCEqRun class. Most of its areguments are contained in the `config` dictionary from the `mceq_config` module. Look into or edit `mceq_config.py`.
#
# If the initialization succeeds it will print out some information according to the debug level.

# %%
mceq_run = MCEqRun(
#provide the string of the interaction model
interaction_model='SIBYLL2.3',
#primary cosmic ray flux model
#support a tuple (primary model class (not instance!), arguments)
primary_model=(pm.Thunman,None),#(pm.HillasGaisser2012, "H3a"),
# Zenith angle in degrees. 0=vertical, 90=horizontal
theta_deg=0.0,
#expand the rest of the options from mceq_config.py
**config
)
# Out:
# InteractionYields::_load(): entering..
# InteractionYields::_load(): Looking for /home/jp/projects/mceq/MCEq/data/SIBYLL23_yields_compact_ledpm.bz2
# DecayYields:_load():: Loading file /home/jp/projects/mceq/MCEq/data/decays_v1_compact.ppd
# MCEqRun::_gen_list_of_particles():Generating particle list.
# MCEqRun::_init_alias_tables():Initializing links to alias IDs.
#
# Hadrons and stable particles:
#
# "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "gamma", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue",
# "k_numu", "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau",
# "k_antinutau", "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau",
# "obs_antinumu", "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-",
# "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL23
# InteractionYields:set_interaction_model():: Model SIBYLL23 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL23 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun_fill_matrices(): Particle production by 3122 explicitly disabled
# MCEqRun_fill_matrices(): Particle production by -3122 explicitly disabled
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981415
#     sum        : 590346233162.0
# D Matrix info:
#     density    : 1.11%
#     shape      : 5368 x 5368
#     nnz        : 318463
#     sum        : 0.20730586438
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.02s
# MCEqRun::_gen_list_of_particles():Generating particle list.
# MCEqRun::set_primary_model():  Thunman None

# %% [markdown]
# Solve and store results
# ----------------------

# %%
#Define equidistant grid in cos(theta)
angles = np.arccos(np.linspace(1,0,11))*180./np.pi

#Power of energy to scale the flux
mag = 3

#obtain energy grid (nver changes) of the solution for the x-axis of the plots
e_grid = mceq_run.e_grid

p_spectrum_flux = []

#Initialize empty grid
for  pmcount, pmodel in enumerate([(pm.HillasGaisser2012,'H3a'),
                                   (pm.HillasGaisser2012,'H4a'),
                                   (pm.GaisserStanevTilav,'3-gen'),
                                   (pm.GaisserStanevTilav,'4-gen')]):
    
    mceq_run.set_primary_model(*pmodel)
    
    flux = {}
    for frac in ['mu_conv','mu_pr','mu_total',
                 'numu_conv','numu_pr','numu_total',
                 'nue_conv','nue_pr','nue_total','nutau_pr']:
        flux[frac] = np.zeros_like(e_grid)
        

    #Sum fluxes, calculated for different angles
    for theta in angles:
        mceq_run.set_theta_deg(theta)
        mceq_run.solve()
        #_conv means conventional (mostly pions and kaons)
        flux['mu_conv'] += (mceq_run.get_solution('conv_mu+', mag)
                           + mceq_run.get_solution('conv_mu-', mag))

        # _pr means prompt (the mother of the muon had a critical energy
        # higher than a D meson. Includes all charm and direct resonance
        # contribution)
        flux['mu_pr'] += (mceq_run.get_solution('pr_mu+', mag)
                         + mceq_run.get_solution('pr_mu-', mag))

        # total means conventional + prompt
        flux['mu_total'] += (mceq_run.get_solution('total_mu+', mag)
                            + mceq_run.get_solution('total_mu-', mag))

        # same meaning of prefixes for muon neutrinos as for muons
        flux['numu_conv'] += (mceq_run.get_solution('conv_numu', mag)
                             + mceq_run.get_solution('conv_antinumu', mag))

        flux['numu_pr'] += (mceq_run.get_solution('pr_numu', mag)
                           + mceq_run.get_solution('pr_antinumu', mag))

        flux['numu_total'] += (mceq_run.get_solution('total_numu', mag)
                              + mceq_run.get_solution('total_antinumu', mag))

        # same meaning of prefixes for electron neutrinos as for muons
        flux['nue_conv'] += (mceq_run.get_solution('conv_nue', mag)
                            + mceq_run.get_solution('conv_antinue', mag))

        flux['nue_pr'] += (mceq_run.get_solution('pr_nue', mag)
                          + mceq_run.get_solution('pr_antinue', mag))

        flux['nue_total'] += (mceq_run.get_solution('total_nue', mag)
                             + mceq_run.get_solution('total_antinue', mag))


        # since there are no conventional tau neutrinos, prompt=total
        flux['nutau_pr'] += (mceq_run.get_solution('total_nutau', mag)
                            + mceq_run.get_solution('total_antinutau', mag))

    #average the results
    for frac in ['mu_conv','mu_pr','mu_total',
                 'numu_conv','numu_pr','numu_total',
                 'nue_conv','nue_pr','nue_total','nutau_pr']:
        flux[frac] = flux[frac]/float(len(angles))
        
    p_spectrum_flux.append((flux,mceq_run.pmodel.sname,mceq_run.pmodel.name))
# Out:
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_theta_deg():  0.0
# Theta selection correponds to cached value, skipping calc.
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.35ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.480517148972 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.32ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.519081115723 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.35ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.596605062485 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.31ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.656124830246 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.81ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.04720306396 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.99ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.36837720871 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   2.48ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.08591914177 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.84ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.98274898529 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   2.53ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 3.75443291664 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.99ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 4.47705197334 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.68ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 6.26624894142 sec
# MCEqRun::set_primary_model():  HillasGaisser2012 H4a
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.61ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.573563098907 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.63ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.639476060867 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.39ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.61109995842 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.62ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.809103965759 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.01s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.68ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.973740100861 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.70ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.16732192039 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.61ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.35269093513 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.61ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.74042105675 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.59ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.35634708405 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.70ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 3.82639884949 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.97ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 7.36118388176 sec
# MCEqRun::set_primary_model():  GaisserStanevTilav 3-gen
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.52ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.541928052902 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.48ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.581213951111 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.97ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.868420124054 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   2.12ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.05993819237 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.85ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.07347106934 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.50ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.03014183044 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.54ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.29304885864 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.66ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.79739284515 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.05s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.63ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.42689990997 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.51ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 3.38184404373 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.70ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 6.35167789459 sec
# MCEqRun::set_primary_model():  GaisserStanevTilav 4-gen
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.53ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.542068004608 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.46ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.574913024902 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.45ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.639140129089 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.46ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.728633165359 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.45ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.841176986694 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.45ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.996737003326 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.46ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.22975206375 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.42ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.53930497169 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.42ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.11027097702 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.48ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 3.33354187012 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.73ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 6.46381902695 sec

# %% [markdown]
# Plot with matplotlib
# --------------------

# %%
for pref, lab in [('numu_',r'\nu_\mu'), 
#                   ('mu_',r'\mu'), 
#                   ('nue_',r'\nu_e')
                 ]:
    plt.figure(figsize=(4.5, 3.5))
    for (flux, p_sname, p_name), col in zip(p_spectrum_flux,['k','r','g','b']):
        
        plt.loglog(e_grid, flux[pref + 'total'], color=col, ls='-', lw=2.5,
                  label=p_sname, alpha=0.4)
        plt.loglog(e_grid, flux[pref + 'conv'], color=col, ls='--', lw=1,
                   label='_nolabel_')
        plt.loglog(e_grid, flux[pref + 'pr'], color=col,ls='-', lw=1, 
                   label='_nolabel_')
    plt.xlim(50,1e9)
    plt.ylim(1e-6,1)
    plt.xlabel(r"$E_{{{0}}}$ [GeV]".format(lab))
    plt.ylabel(r"$\Phi_{" + lab + "}$ (E/GeV)$^{" + str(mag) +" }$" + 
               "(cm$^{2}$ s sr GeV)$^{-1}$")
    plt.legend(loc='upper right')
    plt.tight_layout()
    save(pref + 'flux')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7fc250fb4b87> in <module>()
#      19     plt.legend(loc='upper right')
#      20     plt.tight_layout()
# ---> 21     save(pref + 'flux')
#
# NameError: name 'save' is not defined

# %% [markdown]
# Save as in ASCII file for other types of processing
# ---------------------------------------------------

# %%
np.savetxt(open(os.path.join(desktop, 'my_flux_calculation.txt'),'w'),
zip(e_grid, 
    flux['mu_conv'],flux['mu_pr'],flux['mu_total'],
    flux['numu_conv'],flux['numu_pr'],flux['numu_total'],
    flux['nue_conv'],flux['nue_pr'],flux['nue_total'],
    flux['nutau_pr']),
fmt='%6.5E',
header=('lepton flux scaled with E**{0}. Order (E, mu_conv, mu_pr, mu_total, ' +
        'numu_conv, numu_pr, numu_total, nue_conv, nue_pr, nue_total, ' +
        'nutau_pr').format(mag)
)

# %%
egrid = mceq_run.e_grid
iam_str = mceq_run.iamodel_name
plotloc = os.path.join(os.path.expanduser("~"),'Google Drive/Plots/plots_new_sibyll/ICRC2015')

def make_naked(ax):
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.tick_left()
    
def save(plotname):
    plt.savefig(os.path.join(plotloc,plotname + '.pdf'))
    
def pickle_data(obj, fname):
    import cPickle as pickle
    pickle.dump(obj,open(os.path.join(plotloc,fname + '.pic'),'wb'),protocol=-1)

def unpickle_data(fname):
    import cPickle as pickle
    return pickle.load(open(os.path.join(plotloc,fname + '.pic'),'rb'))
